# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install langchain

# %%
import os

# Example: navigate to a specific folder in Google Drive
os.chdir('/content/drive/MyDrive/cold email generator tool/gmail_generator')

# confirm current directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /content/drive/MyDrive/cold email generator tool/gmail_generator

# %%
# !pip install langchain openai huggingface_hub

# %%
import langchain
print("LangChain version:", langchain.__version__)
# Out:
# LangChain version: 0.3.27

# %%
import sys
print("python executable:", sys.executable)
# Out:
# python executable: /usr/bin/python3

# %%
import sys
# !{sys.executable} -m pip install -U langchain-groq groq langchain

# %%
import sys
# !{sys.executable} -m pip show langchain-groq
# !{sys.executable} -m pip list | grep langchain
# Out:
# Name: langchain-groq
# Version: 0.3.8
# Summary: An integration package connecting Groq and LangChain
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: groq, langchain-core
# Required-by:
# langchain                                0.3.27
# langchain-community                      0.3.29
# langchain-core                           0.3.75
# langchain-groq                           0.3.8
# langchain-text-splitters                 0.3.11

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0,
    groq_api_key="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",
    model_name="llama-3.3-70b-versatile"
)

response = llm.invoke("The first person to land on moon was ")
print(response)
# Out:
# content='The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon\'s surface on July 20, 1969, as part of the Apollo 11 mission. Armstrong famously declared, "That\'s one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 44, 'total_tokens': 121, 'completion_time': 0.104799963, 'prompt_time': 0.010895157, 'queue_time': 0.209103431, 'total_time': 0.11569512}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_2ddfbb0da0', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None} id='run--c1153f97-70a3-446f-a0b0-5d606eb60829-0' usage_metadata={'input_tokens': 44, 'output_tokens': 77, 'total_tokens': 121}

# %%
import sys
print("python executable:", sys.executable)
print("python version:", sys.version)
# Out:
# python executable: /usr/bin/python3
# python version: 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]

# %%
import sys
# !{sys.executable} -m pip install -U langchain langchain-community beautifulsoup4 lxml

# %%
import sys
# !{sys.executable} -m pip show langchain-community
# !{sys.executable} -m pip list | grep langchain || true
# Out:
# Name: langchain-community
# Version: 0.3.29
# Summary: Community contributed LangChain integrations.
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: aiohttp, dataclasses-json, httpx-sse, langchain, langchain-core, langsmith, numpy, pydantic-settings, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:
# langchain                                0.3.27
# langchain-community                      0.3.29
# langchain-core                           0.3.75
# langchain-groq                           0.3.8
# langchain-text-splitters                 0.3.11

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://careers.nike.com/software-engineer-i-backend-itc/job/R-68107")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# Software Engineer I - Backend, ITC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
    """
    *** SCRAPED TEXT FROM WEBSITE:
    {page_data}
    *** INSTRUCTION:
    The scraped text is from the career's page of a website.
    Your job is to extract the job postings and return them in JSON format containing the following keys: role, experience, skills and description.
    Only return the valid JSON.
    *** VALID JSON (NO PREAMBLE).
    """
)

chain_extract = prompt_extract | llm
res = chain_extract.invoke({'page_data': page_data})
print(res.content)
# Out:
# ```json
# {
#   "role": "Software Engineer I - Backend, ITC",
#   "experience": "1+ years of professional experience as a backend Software Engineer",
#   "skills": [
#     "Server-side programming languages such as Java, Python or similar",
#     "Database Expertise: Experience with SQL/NoSQL databases",
#     "API Development for designing and consuming RESTful APIs and web services",
#     "Cloud Technologies: Familiarity with cloud platforms preferably AWS",
#     "Version Control: Familiarity with Git, GitHub, or similar version control tools",
#     "Testing Frameworks: Exposure to unit testing, integration testing, and test-driven development (TDD)",
#     "Problem-Solving: Strong debugging and troubleshooting skills",
#     "Collaboration: Excellent communication and interpersonal skills"
#   ],
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
    """
    *** SCRAPED TEXT FROM WEBSITE:
    {page_data}
    *** INSTRUCTION:
    The scraped text is from the career's page of a website.
    Your job is to extract the job postings and return them in JSON format containing the following keys: role, experience, skills and description.
    Only return the valid JSON.
    *** VALID JSON (NO PREAMBLE).
    """
)

chain_extract = prompt_extract | llm
res = chain_extract.invoke({'page_data': page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Software Engineer I - Backend, ITC',
#  'experience': '1+ years of professional experience as a backend Software Engineer',
#  'skills': ['Server-side programming languages such as Java, Python or similar',
#   'Database Expertise: Experience with SQL/NoSQL databases',
#   'API Development for designing and consuming RESTful APIs and web services',
#   'Cloud Technologies: Familiarity with cloud platforms preferably AWS',
#   'Version Control: Familiarity with Git, GitHub, or similar version control tools',
#   'Testing Frameworks: Exposure to unit testing, integration testing, and test-driven development (TDD)',
#   'Problem-Solving: Strong debugging and troubleshooting skills',
#   'Collaboration: Excellent communication and interpersonal skills'],
# ...

# %%
type(json_res)
# Out:
# dict

# %%
from google.colab import files
import pandas as pd

# Upload file
uploaded = files.upload()

# Read the first uploaded file
for filename in uploaded.keys():
    df = pd.read_csv(filename)

df.head()
# Out:
#      <input type="file" id="files-cb898857-4f04-4380-bf36-44bc9376c11e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb898857-4f04-4380-bf36-44bc9376c11e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

path = '/content/drive/MyDrive/cold email generator tool/my_portfolio.csv'
df = pd.read_csv(path)

df.head()
# Out:
#                            Techstack                                  Links
# 0            React, Node.js, MongoDB    https://example.com/react-portfolio
# 1           Angular,.NET, SQL Server  https://example.com/angular-portfolio
# 2  Vue.js, Ruby on Rails, PostgreSQL      https://example.com/vue-portfolio
# 3              Python, Django, MySQL   https://example.com/python-portfolio
# 4          Java, Spring Boot, Oracle     https://example.com/java-portfolio

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipython-input-1927155411.py in <cell line: 0>()
#       5 collection = client.get_or_create_collection(name="portfolio")
#       6
# ----> 7 if not collection.count():
#       8     for _, row in df.iterrows():
#       9         collection.add(documents=row["Techstack"],
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/models/Collection.py in count(self)
#      39
#      40         """
# ---> 41         return self._client._count(
#      42             collection_id=self.id,
#      43             tenant=self.tenant,
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/rust.py in _count(self, collection_id, tenant, database)
#     332         database: str = DEFAULT_DATABASE,
#     333     ) -> int:
# --> 334         return self.bindings.count(str(collection_id), tenant, database)
#     335
#     336     @override
# ...

# %%
import os, sys
import chromadb
from datetime import datetime

print("python:", sys.executable)
print("chromadb version:", getattr(chromadb, "__version__", "unknown"))
print("cwd:", os.getcwd())

ds = "vectorstore"
if os.path.exists(ds):
    print("Found 'vectorstore' folder. Contents:", os.listdir(ds))
else:
    print("'vectorstore' folder not found.")
# Out:
# python: /usr/bin/python3
# chromadb version: 1.0.21
# cwd: /content/drive/MyDrive/cold email generator tool/gmail_generator
# 'vectorstore' folder not found.

# %%
import shutil, os
from datetime import datetime

ds = "vectorstore"
if os.path.exists(ds):
    bak = f"{ds}_backup_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
    shutil.move(ds, bak)
    print("Moved", ds, "→", bak)
else:
    print("No existing folder to back up.")
# Out:
# No existing folder to back up.

# %%
import chromadb
from chromadb.config import Settings
from chromadb import Client

# Use a fresh folder ./vectorstore (will be created)
settings = Settings(chroma_db_impl="duckdb+parquet", persist_directory="./vectorstore")
client = Client(settings)

# create/get collection
collection = client.get_or_create_collection(name="portfolio")
print("Collection ready. Count:", collection.count())
# Out:
# Collection ready. Count: 0

# %%
import uuid

# assume `df` is your pandas DataFrame already loaded in Colab
# ensure the columns exist
print(df.columns)

# convert to lists and fill NaNs
docs = df['Techstack'].astype(str).tolist()
metadatas = [{"links": str(x)} for x in df['Links'].fillna('').tolist()]
ids = [str(uuid.uuid4()) for _ in docs]

# only add if collection empty (or always add depending on your logic)
if collection.count() == 0:
    collection.add(documents=docs, metadatas=metadatas, ids=ids)
    # For some backends you can also call persist
    try:
        client.persist()
    except Exception:
        pass

print("After adding, count:", collection.count())
# Out:
# Index(['Techstack', 'Links'], dtype='object')
# After adding, count: 20

# %%
for doc, meta in zip(docs, metadatas):
    collection.add(documents=[doc], metadatas=[meta], ids=[str(uuid.uuid4())])

# %%
print("Final count:", collection.count())

# a simple similarity search (query_texts -> returns matches)
res = collection.query(query_texts=["python development"], n_results=3)
print(res)
# Out:
# Final count: 40
# {'ids': [['fc5e5a6b-acc4-4ff4-b34e-c568efa5f81a', 'f3ab71a0-cc94-44b5-9ac6-efd6d4e035e5', 'dbf7b043-8080-4f9b-9241-d181ef88aea4']], 'embeddings': None, 'documents': [['Machine Learning, Python, TensorFlow', 'Machine Learning, Python, TensorFlow', 'Python, Django, MySQL']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[{'links': 'https://example.com/ml-python-portfolio'}, {'links': 'https://example.com/ml-python-portfolio'}, {'links': 'https://example.com/python-portfolio'}]], 'distances': [[0.9329714775085449, 0.9329714775085449, 0.9639254808425903]]}

# %%
import os
for root, dirs, files in os.walk('vectorstore_backup_'):
    for f in files:
        if f.endswith(('.db', '.sqlite', '.parquet')):
            print(root, f)

# %%
import sys, os, importlib.util
print("python:", sys.executable)
print("chromadb version:", getattr(chromadb, "__version__", "unknown"))
print("folder listing:", os.listdir('.'))
print("vectorstore exists?:", os.path.exists('vectorstore'))
print("find_spec:", importlib.util.find_spec("chromadb"))
# Out:
# python: /usr/bin/python3
# chromadb version: 1.0.21
# folder listing: ['my_portfolio.csv', 'my_portfolio (1).csv', 'vectorstore']
# vectorstore exists?: True
# find_spec: ModuleSpec(name='chromadb', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fb2ae990ec0>, origin='/usr/local/lib/python3.12/dist-packages/chromadb/__init__.py', submodule_search_locations=['/usr/local/lib/python3.12/dist-packages/chromadb'])

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipython-input-1927155411.py in <cell line: 0>()
#       5 collection = client.get_or_create_collection(name="portfolio")
#       6
# ----> 7 if not collection.count():
#       8     for _, row in df.iterrows():
#       9         collection.add(documents=row["Techstack"],
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/models/Collection.py in count(self)
#      39
#      40         """
# ---> 41         return self._client._count(
#      42             collection_id=self.id,
#      43             tenant=self.tenant,
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/rust.py in _count(self, collection_id, tenant, database)
#     332         database: str = DEFAULT_DATABASE,
#     333     ) -> int:
# --> 334         return self.bindings.count(str(collection_id), tenant, database)
#     335
#     336     @override
# ...

# %%
# Cell 1 — inspect environment & vectorstore folder
import sys, os, traceback

print("Python executable:", sys.executable)
print("Python version:", sys.version.splitlines()[0])

try:
    import chromadb
    print("chromadb version:", getattr(chromadb, "__version__", "unknown"))
except Exception as e:
    print("chromadb import failed:", e)

ds = "vectorstore"
print("cwd:", os.getcwd())
print(f"'{ds}' exists?:", os.path.exists(ds))
if os.path.exists(ds):
    for root, dirs, files in os.walk(ds):
        print("Contents of", root, "->", files)
        break
# Out:
# Python executable: /usr/bin/python3
# Python version: 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# chromadb version: 1.0.21
# cwd: /content/drive/MyDrive/cold email generator tool/gmail_generator
# 'vectorstore' exists?: True
# Contents of vectorstore -> ['chroma.sqlite3']

# %%
# Cell 2 — backup vectorstore if present
import os, shutil, datetime

ds = "vectorstore"
if os.path.exists(ds):
    bak = f"{ds}_backup_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    shutil.move(ds, bak)
    print("Backed up", ds, "→", bak)
else:
    print("No existing 'vectorstore' to back up.")
# Out:
# Backed up vectorstore → vectorstore_backup_20250913_195348

# %%
# Cell 3 — install (then restart the runtime)
import sys
# !{sys.executable} -m pip install -U chromadb duckdb pyarrow
print("Install completed. NOW restart the runtime (Runtime → Restart runtime...) then run Cell 4.")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 16.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 21.0.0 which is incompatible.
# pylibcudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 21.0.0 which is incompatible.
# ...
# Install completed. NOW restart the runtime (Runtime → Restart runtime...) then run Cell 4.

# %%
# Cell 4 — create client with duckdb+parquet and test
from chromadb.config import Settings
import chromadb

settings = Settings(chroma_db_impl="duckdb+parquet", persist_directory="./vectorstore")
client = chromadb.Client(settings)

# create/get collection
collection = client.get_or_create_collection(name="portfolio")
print("Collection created/get:", collection)
try:
    print("Collection.count():", collection.count())
except Exception as e:
    print("Error calling collection.count():", type(e).__name__, e)
# Out:
# Collection created/get: Collection(name=portfolio)
# Collection.count(): 40

# %%
# Cell 5 — add df rows in batch (safe and fast)
import uuid

# If you haven't loaded df, load it here (example)
# import pandas as pd
# df = pd.read_csv('/content/drive/MyDrive/path/to/your.csv')

# Ensure df exists:
try:
    df
except NameError:
    raise RuntimeError("DataFrame 'df' not found in notebook. Load your CSV into df before running this cell.")

# Prepare lists
docs = df['Techstack'].astype(str).tolist()
metadatas = [{"links": str(x)} for x in df['Links'].fillna('').tolist()]
ids = [str(uuid.uuid4()) for _ in docs]

# Only add if empty (or change logic as you need)
if collection.count() == 0:
    collection.add(documents=docs, metadatas=metadatas, ids=ids)
    # persist (some backends require explicit persist)
    try:
        client.persist()
    except Exception:
        pass

print("Added documents. New count:", collection.count())
# Out:
# Added documents. New count: 40

# %%
for doc, meta in zip(docs, metadatas):
    collection.add(documents=[doc], metadatas=[meta], ids=[str(uuid.uuid4())])

# %%
# Cell 6 — check files inside vectorstore and attempt to list sqlite tables if sqlite file found
import os, glob
files = list(glob.glob("vectorstore/**/*", recursive=True))
print("vectorstore files (first 100):", files[:100])

# If any .db or .sqlite file is present, inspect its tables
sqlite_files = [f for f in files if f.endswith(('.db', '.sqlite'))]
print("sqlite files:", sqlite_files)
if sqlite_files:
    import sqlite3
    for sfile in sqlite_files:
        print("Inspecting", sfile)
        try:
            conn = sqlite3.connect(sfile)
            cur = conn.cursor()
            cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
            print("Tables:", cur.fetchall())
            conn.close()
        except Exception as e:
            print("Could not open sqlite file:", e)
# Out:
# vectorstore files (first 100): []
# sqlite files: []

# %%
# ONE-CELL: backup existing store, install deps, create fresh store and import df (if df exists)
import sys, os, shutil, datetime, uuid

ds = "vectorstore"
if os.path.exists(ds):
    bak = f"{ds}_backup_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    shutil.move(ds, bak)
    print("Backed up", ds, "→", bak)
else:
    print("No existing vectorstore found.")

# install dependencies (may need restart afterwards)
# !{sys.executable} -m pip install -U chromadb duckdb pyarrow

print("If new packages were installed, please restart the runtime now and re-run this cell from top (skip install) to create the store and import df.")
# After a restart, run the second half of this cell manually:
# Out:
# No existing vectorstore found.
# ...
# If new packages were installed, please restart the runtime now and re-run this cell from top (skip install) to create the store and import df.

# %%
from chromadb.config import Settings
import chromadb
import uuid
import os
import shutil
import datetime

# Use a fresh folder ./vectorstore (will be created)
persist_directory = "./vectorstore"

# Backup existing vectorstore if it exists
if os.path.exists(persist_directory):
    bak = f"{persist_directory}_backup_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    try:
        shutil.move(persist_directory, bak)
        print(f"Backed up {persist_directory} → {bak}")
    except Exception as e:
        print(f"Error backing up {persist_directory}: {e}")


# Initialize the client with the persist_directory
client = chromadb.PersistentClient(path=persist_directory)

collection = client.get_or_create_collection(name="portfolio")
print("Collection count after initialization:", collection.count())

# import if df exists and collection is empty
try:
    df # Check if df exists
    docs = df['Techstack'].astype(str).tolist()
    metadatas = [{"links": str(x)} for x in df['Links'].fillna('').tolist()]
    ids = [str(uuid.uuid4()) for _ in docs]

    if collection.count() == 0:
        collection.add(documents=docs, metadatas=metadatas, ids=ids)
        try: client.persist()
        except: pass
        print("Added documents to collection.")
    else:
        print("Collection is not empty, skipping data import.")

    print("Final collection count:", collection.count())
except NameError:
    print("DataFrame 'df' not found; nothing imported.")
except Exception as e:
    print(f"An error occurred during data import: {e}")
# Out:
# Collection count after initialization: 40
# Collection is not empty, skipping data import.
# Final collection count: 40

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import os

# create a directory for chromadb
db_path = "/content/vectorstore"
os.makedirs(db_path, exist_ok=True)

# %%
import chromadb

client = chromadb.PersistentClient(path=db_path)
collection = client.get_or_create_collection(name="portfolio")

# %%
import uuid

docs = df["Techstack"].astype(str).tolist()
metas = [{"links": str(l)} for l in df["Links"].tolist()]
ids = [str(uuid.uuid4()) for _ in range(len(docs))]

if collection.count() == 0:
    collection.add(documents=docs, metadatas=metas, ids=ids)

# %%
db_path = "/content/drive/MyDrive/vectorstore"
os.makedirs(db_path, exist_ok=True)

client = chromadb.PersistentClient(path=db_path)

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipython-input-1927155411.py in <cell line: 0>()
#       2 import chromadb
#       3
# ----> 4 client = chromadb.PersistentClient('vectorstore')
#       5 collection = client.get_or_create_collection(name="portfolio")
#       6
#
# /usr/local/lib/python3.12/dist-packages/chromadb/__init__.py in PersistentClient(path, settings, tenant, database)
#     165     database = str(database)
#     166
# --> 167     return ClientCreator(tenant=tenant, database=database, settings=settings)
#     168
#     169
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/client.py in __init__(self, tenant, database, settings)
#      94         # Create an admin client for verifying that databases and tenants exist
#      95         self._admin_client = AdminClient.from_system(self._system)
# ...

# %%
import os
import uuid
import chromadb

# Ensure path exists
db_path = "/content/vectorstore"
os.makedirs(db_path, exist_ok=True)

# Persistent client
client = chromadb.PersistentClient(path=db_path)

# Create / get collection
collection = client.get_or_create_collection(name="portfolio")

# Insert if collection is empty
if collection.count() == 0:
    for _, row in df.iterrows():
        collection.add(
            documents=[str(row["Techstack"])],            # must be a list
            metadatas=[{"links": str(row["Links"])}],     # must be a list of dicts
            ids=[str(uuid.uuid4())]                       # list of ids
        )

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/python-portfolio'}, {'links': 'https://example.com/magento-portfolio'}], [{'links': 'https://example.com/react-portfolio'}, {'links': 'https://example.com/magento-portfolio'}], [{'links': 'https://example.com/wordpress-portfolio'}, {'links': 'https://example.com/flutter-portfolio'}], [{'links': 'https://example.com/react-portfolio'}, {'links': 'https://example.com/magento-portfolio'}], [{'links': 'https://example.com/wordpress-portfolio'}, {'links': 'https://example.com/magento-portfolio'}], [{'links': 'https://example.com/angular-portfolio'}, {'links': 'https://example.com/ios-portfolio'}], [{'links': 'https://example.com/python-portfolio'}, {'links': 'https://example.com/android-portfolio'}], [{'links': 'https://example.com/android-portfolio'}, {'links': 'https://example.com/vue-portfolio'}]]

# %%
try:
    display(json_res)
except NameError:
    print("Variable 'json_res' not found. Please ensure you have extracted job data into a variable named 'json_res'.")
# Out:
# {'role': 'Software Engineer I - Backend, ITC',
#  'experience': '1+ years of professional experience as a backend Software Engineer',
#  'skills': ['Server-side programming languages such as Java, Python or similar',
#   'Database Expertise: Experience with SQL/NoSQL databases',
#   'API Development for designing and consuming RESTful APIs and web services',
#   'Cloud Technologies: Familiarity with cloud platforms preferably AWS',
#   'Version Control: Familiarity with Git, GitHub, or similar version control tools',
#   'Testing Frameworks: Exposure to unit testing, integration testing, and test-driven development (TDD)',
#   'Problem-Solving: Strong debugging and troubleshooting skills',
#   'Collaboration: Excellent communication and interpersonal skills'],
# ...

# %%
job = json_res
job['skills']
# Out:
# ['Server-side programming languages such as Java, Python or similar',
#  'Database Expertise: Experience with SQL/NoSQL databases',
#  'API Development for designing and consuming RESTful APIs and web services',
#  'Cloud Technologies: Familiarity with cloud platforms preferably AWS',
#  'Version Control: Familiarity with Git, GitHub, or similar version control tools',
#  'Testing Frameworks: Exposure to unit testing, integration testing, and test-driven development (TDD)',
#  'Problem-Solving: Strong debugging and troubleshooting skills',
#  'Collaboration: Excellent communication and interpersonal skills']

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}

        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools.
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability,
        process optimization, cost reduction, and heightened overall efficiency.
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ.
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):

        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Backend Software Engineering Services for Your Business
#
# Dear Hiring Manager,
#
# I came across your job posting for a Software Engineer I - Backend, ITC, and I'm excited to introduce AtliQ, a leading AI & Software Consulting company that can help you fulfill your backend software engineering needs. With our expertise in designing and developing scalable web applications and services, we're confident that we can deliver high-quality solutions that meet your requirements.
#
# Our team of skilled software engineers has extensive experience in server-side programming languages such as Java, Python, and similar technologies. We're well-versed in database expertise, including SQL/NoSQL databases, and have a strong background in API development for designing and consuming RESTful APIs and web services. Our familiarity with cloud platforms, particularly AWS, and version control tools like Git and GitHub, ensures seamless integration and collaboration.
#
# ...
